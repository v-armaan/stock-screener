# %%
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.graph_objects as go
import sys
sys.path.append("../")
from src import calculations,data_cleaning,data_import,name_to_Ticker
from plotly.subplots import make_subplots

# %%
df=yf.Ticker("AAPL").history(period="1y")

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437234  225.686314  222.956393  224.072266
# 2025-08-22 00:00:00-04:00  225.337593  228.246845  224.580396  226.921738
# 2025-08-25 00:00:00-04:00  225.646469  228.456098  225.397389  226.323975
# 2025-08-26 00:00:00-04:00  226.035027  228.645395  223.863057  228.466049
# ...                               ...         ...         ...         ...
# 2026-08-14 00:00:00-04:00  306.000000  307.489990  304.299988  305.929993
# 2026-08-17 00:00:00-04:00  306.209991  307.660004  302.940002  305.589996
# 2026-08-18 00:00:00-04:00  307.579987  311.489990  305.739990  310.029999
# 2026-08-19 00:00:00-04:00  310.140015  319.279999  309.600006  316.829987
# 2026-08-20 00:00:00-04:00  317.454987  320.279999  316.000000  316.640015
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df=data_cleaning.data_clean(df)

# %%
ohlcv=df[["Open","High","Low","Close","Volume"]].copy()

# %%
# fig=go.Figure(data=[go.Candlestick(x=df.index,open=df["Open"],high=df["High"],low=df["Low"],close=df["Close"],name="AAPL")])
# fig.update_layout(
#     plot_bgcolor="black",
#     height=1000
# )

# %%
fig=make_subplots(rows=2,cols=1,shared_xaxes=True,vertical_spacing=0.05,row_heights=[0.75,0.25])
#candlestick
fig.add_trace(go.Candlestick(x=df.index,open=df["Open"],high=df["High"],low=df["Low"],close=df["Close"],name="Price"),row=1,col=1)
#sma
ma=calculations.calculate_moving_averages(df)
fig.add_trace(go.Scatter(x=df.index,y=ma["SMA_20"],name="SMA 20",mode="lines"),row=1,col=1)
#ema
fig.add_trace(go.Scatter(x=df.index,y=ma["EMA_20"],name="EMA 20",mode="lines"),row=1,col=1)
#volume
volume_colors=[]
for i in range(len(df)):
    if df["Close"].iloc[i]>df["Open"].iloc[i]:
        volume_colors.append("green")
    else:
        volume_colors.append("red")
# fig.add_trace(go.Bar(x=df.index,y=df["Volume"],name="Volume",marker_color=volume_colors),row=2,col=1)
fig.update_layout(
    height=800,
    # xaxis_rangeslider_visible=False,
    # plot_bgcolor="black"
)
fig.update_xaxes(
    showline=False,
    mirror=False
)

fig.show()

# %%
#plotting rsi

# %%
rsi=calculations.calc_rsi(df)
fig_rsi=go.Figure()
fig_rsi.add_trace(
    go.Scatter(
        x=rsi.index,
        y=rsi["RSI"],
        mode="lines",
        name="RSI"
    )
)
#overbought
fig_rsi.add_hline(
    y=70,
    line_dash="dash",
    annotation_text="overbought(70)"
)
#oversold
fig_rsi.add_hline(
    y=30,
    line_dash="dash",
    annotation_text="oversold(30)"
)
#midline
fig_rsi.add_hline(
    y=50,
    line_dash="dot",
    annotation_text="50"
)
fig_rsi.update_layout(
    title="RSI 14",
    xaxis_title="Date",
    yaxis=dict(range=[0,100],title="RSI"),
    
)

# %%
#plotting atr
df=yf.Ticker("AAPL").history(period="2y")
atr=calculations.calculate_atr(df)
fig_atr=go.Figure()
fig_atr.add_trace(
    go.Scatter(
        x=atr.index,
        y=atr["atr"],
        mode="lines",
        name="ATR"
    )
)
fig_atr.update_layout(
    title="ATR 14",
    xaxis_title="Date",
    yaxis_title="ATR",
    height=400
)

# %%
fig=make_subplots(rows=2,cols=1,shared_xaxes=True,vertical_spacing=0.05,row_heights=[0.75,0.25])
#candlestick
fig.add_trace(go.Candlestick(x=df.index,open=df["Open"],high=df["High"],low=df["Low"],close=df["Close"],name="Price"),row=1,col=1)
#sma
ma=calculations.calculate_moving_averages(df)
bb=calculations.calculate_bollinger_bands(df)
fig.add_trace(go.Scatter(x=ma.index,y=ma["SMA_20"],name="SMA 20",mode="lines"),row=1,col=1)
#ema
fig.add_trace(go.Scatter(x=ma.index,y=ma["EMA_20"],name="EMA 20",mode="lines"),row=1,col=1)
#bollinger bands
fig.add_trace(go.Scatter(x=bb.index,y=bb["UPPER_BAND"],name="BB UPPER",mode="lines"),row=1,col=1)
fig.add_trace(go.Scatter(x=bb.index,y=bb["MIDDLE_BAND"],name="BB MIDDLE",mode="lines"),row=1,col=1)
fig.add_trace(go.Scatter(x=bb.index,y=bb["LOWER_BAND"],name="BB LOWER",mode="lines"),row=1,col=1)

#volume
volume_colors=[]
for i in range(len(df)):
    if df["Close"].iloc[i]>df["Open"].iloc[i]:
        volume_colors.append("green")
    else:
        volume_colors.append("red")
fig.add_trace(go.Bar(x=df.index,y=df["Volume"],name="Volume",marker_color=volume_colors),row=2,col=1)
fig.update_layout(
    height=800,
    xaxis_rangeslider_visible=False,
    # plot_bgcolor="black"
)

# %%
fig=make_subplots(rows=2,cols=1,shared_xaxes=True,vertical_spacing=0.05,row_heights=[0.75,0.25])
#candlestick
fig.add_trace(go.Candlestick(x=df.index,open=df["Open"],high=df["High"],low=df["Low"],close=df["Close"],name="Price"),row=1,col=1)
bb=calculations.calculate_bollinger_bands(df)
fig.add_trace(go.Scatter(x=ma.index,y=ma["SMA_20"],name="SMA 20",mode="lines"),row=1,col=1)
#
fig.add_trace(go.Scatter(x=ma.index,y=ma["EMA_20"],name="EMA 20",mode="lines"),row=1,col=1)
#bollinger bands
fig.add_trace(go.Scatter(x=bb.index,y=bb["UPPER_BAND"],name="BB UPPER",mode="lines"),row=1,col=1)
fig.add_trace(go.Scatter(x=bb.index,y=bb["MIDDLE_BAND"],name="BB MIDDLE",mode="lines"),row=1,col=1)
fig.add_trace(go.Scatter(x=bb.index,y=bb["LOWER_BAND"],name="BB LOWER",mode="lines"),row=1,col=1)

#volume
volume_colors=[]
for i in range(len(df)):
    if df["Close"].iloc[i]>df["Open"].iloc[i]:
        volume_colors.append("green")
    else:
        volume_colors.append("red")
fig.add_trace(go.Bar(x=df.index,y=df["Volume"],name="Volume",marker_color=volume_colors),row=2,col=1)
fig.update_layout(
    height=800,
    xaxis_rangeslider_visible=False,
    # plot_bgcolor="black"
)
fig.update_xaxes(
    showline=False,
    mirror=False
)

# %%
a=10
print(a)
# Out:
# 10

# %%
a=20
print(a)
# Out:
# 20

# %%
macd = calculations.calculate_macd(df)

fig_macd = go.Figure()

# MACD line
fig_macd.add_trace(
    go.Scatter(
        x=macd.index,
        y=macd["MACD"],
        mode="lines",
        name="MACD"
    )
)

# Signal line
fig_macd.add_trace(
    go.Scatter(
        x=macd.index,
        y=macd["MACD_SIGNAL"],
        mode="lines",
        name="Signal"
    )
)

# Histogram
fig_macd.add_trace(
    go.Bar(
        x=macd.index,
        y=macd["MACD_HISTOGRAM"],
        name="Histogram"
    )
)
fig_macd.update_layout(
    bargap=0
)
fig_macd.show()

# %%
def plot_obv(df):

    obv=calculations.volume_metrics(df)["OBV"]

    fig_obv = go.Figure()

    fig_obv.add_trace(
        go.Scatter(
            x=obv.index,
            y=obv["OBV"],
            mode="lines",
            name="OBV"
        )
    )

    fig_obv.update_layout(
        title="OBV",
        xaxis_title="Date",
        yaxis=dict(title="OBV"),
        height=400
    )

    fig_obv = remove_non_trading_days(fig_obv, df)

    return fig_obv
