# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %% [markdown]
# IMPORTING DATA FROM YFINANCE

# %%
data0=yf.Ticker("AAPL")
data0
# Out:
# yfinance.Ticker object <AAPL>

# %%
data0.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
df=data0.history(period="1y")

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-15 00:00:00-04:00  233.138790  233.417758  228.495937  230.737656
# 2025-08-18 00:00:00-04:00  230.847254  232.262026  229.263109  230.040237
# 2025-08-19 00:00:00-04:00  230.428808  232.012952  228.505918  229.711456
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437249  225.686329  222.956408  224.072281
# ...                               ...         ...         ...         ...
# 2026-08-10 00:00:00-04:00  306.829987  308.260010  304.609985  308.260010
# 2026-08-11 00:00:00-04:00  307.750000  309.970001  302.790009  304.910004
# 2026-08-12 00:00:00-04:00  305.100006  305.660004  300.570007  302.250000
# 2026-08-13 00:00:00-04:00  304.209991  306.000000  302.049988  305.260010
# 2026-08-14 00:00:00-04:00  306.000000  307.489990  304.299988  305.929993
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 251 entries, 2025-08-15 00:00:00-04:00 to 2026-08-14 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          251 non-null    float64
#  1   High          251 non-null    float64
#  2   Low           251 non-null    float64
#  3   Close         251 non-null    float64
#  4   Volume        251 non-null    int64
#  5   Dividends     251 non-null    float64
#  6   Stock Splits  251 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 15.7 KB

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-15 00:00:00-04:00  233.138790  233.417758  228.495937  230.737656
# 2025-08-18 00:00:00-04:00  230.847254  232.262026  229.263109  230.040237
# 2025-08-19 00:00:00-04:00  230.428808  232.012952  228.505918  229.711456
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437249  225.686329  222.956408  224.072281
# ...                               ...         ...         ...         ...
# 2026-08-10 00:00:00-04:00  306.829987  308.260010  304.609985  308.260010
# 2026-08-11 00:00:00-04:00  307.750000  309.970001  302.790009  304.910004
# 2026-08-12 00:00:00-04:00  305.100006  305.660004  300.570007  302.250000
# 2026-08-13 00:00:00-04:00  304.209991  306.000000  302.049988  305.260010
# 2026-08-14 00:00:00-04:00  306.000000  307.489990  304.299988  305.929993
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
##FINDING DATES WHERE DIVIDENDS WERE PAID
df[df["Dividends"]!=0]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-11-10 00:00:00-05:00  268.229883  272.986954  266.733955  268.698608
# 2026-02-09 00:00:00-05:00  277.414946  277.704438  271.216017  274.130798
# 2026-05-11 00:00:00-04:00  291.728417  293.626774  289.979925  292.427795
# 2026-08-10 00:00:00-04:00  306.829987  308.260010  304.609985  308.260010
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-11-10 00:00:00-05:00  41312400       0.26           0.0
# 2026-02-09 00:00:00-05:00  44623400       0.26           0.0
# 2026-05-11 00:00:00-04:00  42247300       0.27           0.0
# 2026-08-10 00:00:00-04:00  44812500       0.27           0.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 251 entries, 2025-08-15 00:00:00-04:00 to 2026-08-14 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          251 non-null    float64
#  1   High          251 non-null    float64
#  2   Low           251 non-null    float64
#  3   Close         251 non-null    float64
#  4   Volume        251 non-null    int64
#  5   Dividends     251 non-null    float64
#  6   Stock Splits  251 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 15.7 KB

# %%
#how many trading days are there in the data
print(df.shape[0])
# Out:
# 251

# %%
#average
print("average vol=",np.mean(df['Volume']))
# Out:
# average vol= 49763979.6812749

# %%
#date which had the highest volume
df[df["Volume"]==df["Volume"].max()]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-06-26 00:00:00-04:00  274.763028  285.703605  273.973701  283.535461
#
#                               Volume  Dividends  Stock Splits
# Date
# 2026-06-26 00:00:00-04:00  261775500        0.0           0.0

# %%
df["Volume"].max()
# Out:
# np.int64(261775500)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='str')

# %%
#day with the highest price
display("highest priced:",df[df['High']==df["High"].max()])
display("lowest priced:",df[df["Low"]==df["Low"].min()])
# Out:
# 'highest priced:'
#                                  Open        High         Low      Close  \
# Date
# 2026-07-29 00:00:00-04:00  339.437272  344.273097  337.059318  337.89859
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026
10)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-15 00:00:00-04:00  233.138790  233.417758  228.495937  230.737656
# 2025-08-18 00:00:00-04:00  230.847254  232.262026  229.263109  230.040237
# 2025-08-19 00:00:00-04:00  230.428808  232.012952  228.505918  229.711456
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437249  225.686329  222.956408  224.072281
# 2025-08-22 00:00:00-04:00  225.337608  228.246860  224.580411  226.921753
# 2025-08-25 00:00:00-04:00  225.646469  228.456098  225.397389  226.323975
# 2025-08-26 00:00:00-04:00  226.035012  228.645379  223.863042  228.466034
# 2025-08-27 00:00:00-04:00  227.768623  230.050188  227.419905  229.641708
# 2025-08-28 00:00:00-04:00  229.970500  232.550964  228.495936  231.704086
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-08-15 00:00:00-04:00  56038700        0.0           0.0
# ...

# %%
df.head(25)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-15 00:00:00-04:00  233.138790  233.417758  228.495937  230.737656
# 2025-08-18 00:00:00-04:00  230.847254  232.262026  229.263109  230.040237
# 2025-08-19 00:00:00-04:00  230.428808  232.012952  228.505918  229.711456
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437249  225.686329  222.956408  224.072281
# 2025-08-22 00:00:00-04:00  225.337608  228.246860  224.580411  226.921753
# 2025-08-25 00:00:00-04:00  225.646469  228.456098  225.397389  226.323975
# 2025-08-26 00:00:00-04:00  226.035012  228.645379  223.863042  228.466034
# 2025-08-27 00:00:00-04:00  227.768623  230.050188  227.419905  229.641708
# 2025-08-28 00:00:00-04:00  229.970500  232.550964  228.495936  231.704086
# 2025-08-29 00:00:00-04:00  231.654263  232.521071  230.518459  231.285629
# 2025-09-02 00:00:00-04:00  228.406271  230.000388  226.134663  228.874542
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2025-08-15 00:00:00-04:00', '2025-08-18 00:00:00-04:00',
#                '2025-08-19 00:00:00-04:00', '2025-08-20 00:00:00-04:00',
#                '2025-08-21 00:00:00-04:00', '2025-08-22 00:00:00-04:00',
#                '2025-08-25 00:00:00-04:00', '2025-08-26 00:00:00-04:00',
#                '2025-08-27 00:00:00-04:00', '2025-08-28 00:00:00-04:00',
#                ...
#                '2026-08-03 00:00:00-04:00', '2026-08-04 00:00:00-04:00',
#                '2026-08-05 00:00:00-04:00', '2026-08-06 00:00:00-04:00',
#                '2026-08-07 00:00:00-04:00', '2026-08-10 00:00:00-04:00',
#                '2026-08-11 00:00:00-04:00', '2026-08-12 00:00:00-04:00',
#                '2026-08-13 00:00:00-04:00', '2026-08-14 00:00:00-04:00'],
#               dtype='datetime64[s, America/New_York]', name='Date', length=251, freq=None)

# %%
df.groupby(df.index.month)["Close"].mean().idxmax()
# Out:
# np.int32(7)

# %%
df.groupby(df.index.month)["High"].max()
# Out:
# Date
# 1     277.085768
# 2     280.147456
# 3     266.055186
# 4     275.508349
# 5     314.728576
# 6     317.126501
# 7     344.273097
# 8     316.017470
# 9     256.651929
# 10    276.299373
# 11    279.618887
# 12    287.836529
# Name: High, dtype: float64

# %%
df.groupby(df.index.month)["Low"].min()
# Out:
# Date
# 1     242.759224
# 2     254.994942
# 3     245.072643
# 4     245.262308
# 5     274.370331
# 6     273.514115
# 7     288.950814
# 8     222.956408
# 9     225.118433
# 10    243.101979
# 11    264.599780
# 12    266.225345
# Name: Low, dtype: float64

# %%
##no. of trading days in each month
df.index.days_in_month
# Out:
# Index([31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#        ...
#        31, 31, 31, 31, 31, 31, 31, 31, 31, 31],
#       dtype='int32', name='Date', length=251)

# %%
df.groupby(df.index.month)["Dividends"].sum()
# Out:
# Date
# 1     0.00
# 2     0.26
# 3     0.00
# 4     0.00
# 5     0.27
# 6     0.00
# 7     0.00
# 8     0.27
# 9     0.00
# 10    0.00
# 11    0.26
# 12    0.00
# Name: Dividends, dtype: float64

# %% [markdown]
# TO GET A TICKER FROM THE COMPANY NAME ENTERED

# %%
from yahooquery import search
result=search("microsoft")
result
# Out:
# {'explains': [],
#  'count': 15,
#  'quotes': [{'exchange': 'NMS',
#    'shortname': 'Microsoft Corporation',
#    'quoteType': 'EQUITY',
#    'symbol': 'MSFT',
#    'index': 'quotes',
#    'score': 22351.0,
#    'typeDisp': 'Equity',
#    'longname': 'Microsoft Corporation',
#    'exchDisp': 'NASDAQ',
#    'sector': 'Technology',
#    'sectorDisp': 'Technology',
#    'industry': 'Software—Infrastructure',
#    'industryDisp': 'Software—Infrastructure',
#    'dispSecIndFlag': True,
#    'isYahooFinance': True},
#   {'exchange': 'GER',
#    'shortname': 'MICROSOFT CORP.               R',
#    'quoteType': 'EQUITY',
#    'symbol': 'MSF.DE',
#    'index': 'quotes',
#    'score': 20007.0,
#    'typeDisp': 'Equity',
#    'longname': 'Microsoft Corporation',
#    'exchDisp': 'XETRA',
#    'sector': 'Technology',
#    'sectorDisp': 'Technology',
#    'industry': 'Software—Infrastructure',
#    'industryDisp': 'Software—Infrastructure',
#    'isYahooFinance': True},
#   {'exchange': 'NEO',
# ...

# %%
x=result.keys()
print(x)
print(result['quotes'])
type(result['quotes'])
"""
the result is a dictionary but the quotes key has a list stored inside it and the list has dicts stored in it as elements so
result(dict)-->quotes(list)--->dict elements
"""
# Out:
# dict_keys(['explains', 'count', 'quotes', 'news', 'nav', 'lists', 'researchReports', 'screenerFieldResults', 'totalTime', 'timeTakenForQuotes', 'timeTakenForNews', 'timeTakenForAlgowatchlist', 'timeTakenForPredefinedScreener', 'timeTakenForCrunchbase', 'timeTakenForNav', 'timeTakenForResearchReports', 'timeTakenForQuestions', 'timeTakenForScreenerField', 'timeTakenForCulturalAssets', 'timeTakenForSearchLists'])
# ...

# %%
result['quotes'][0]['symbol']#####found the ticker
# Out:
# 'MSFT'

# %%
aplr=search("AAPL")
apl=aplr['quotes'][0]['symbol']
apl
# Out:
# 'AAPL'

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-08-15 00:00:00-04:00  233.138790  233.417758  228.495937  230.737656
# 2025-08-18 00:00:00-04:00  230.847254  232.262026  229.263109  230.040237
# 2025-08-19 00:00:00-04:00  230.428808  232.012952  228.505918  229.711456
# 2025-08-20 00:00:00-04:00  229.133582  229.621784  224.939085  225.178192
# 2025-08-21 00:00:00-04:00  225.437249  225.686329  222.956408  224.072281
# ...                               ...         ...         ...         ...
# 2026-08-10 00:00:00-04:00  306.829987  308.260010  304.609985  308.260010
# 2026-08-11 00:00:00-04:00  307.750000  309.970001  302.790009  304.910004
# 2026-08-12 00:00:00-04:00  305.100006  305.660004  300.570007  302.250000
# 2026-08-13 00:00:00-04:00  304.209991  306.000000  302.049988  305.260010
# 2026-08-14 00:00:00-04:00  306.000000  307.489990  304.299988  305.929993
#
#                              Volume  Dividends  Stock Splits
# Date
# ...
